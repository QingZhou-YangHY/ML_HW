# %%
# Homework Description
- English to Chinese (Traditional) Translation
  - Input: an English sentence         (e.g.		tom is a student .)
  - Output: the Chinese translation  (e.g. 		湯姆 是 個 學生 。)

- TODO
    - Train a simple RNN seq2seq to acheive translation
    - Switch to transformer model to boost performance
    - Apply Back-translation to furthur boost performance

# %%
# !pip install 'torch>=1.6.0' editdistance matplotlib sacrebleu sacremoses sentencepiece tqdm wandb
# !pip install --upgrade jupyter ipywidgets 
print("pip install already")
# Out:
# ...
# pip install already

# %%
# !git clone https://github.com/pytorch/fairseq.git
# !cd fairseq && git checkout 9a1c497
# !pip install --upgrade ./fairseq/
print("pip install already")
# Out:
# fatal: destination path 'fairseq' already exists and is not an empty directory.
# HEAD is now at 9a1c4970 Make Hydra logging work with DDP (#1568)
# Processing ./fairseq
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for fairseq: filename=fairseq-1.0.0a0+9a1c497-cp311-cp311-linux_x86_64.whl size=2275527 sha256=3aed4646cacfa76dda54ec0cd924e3bc057db65ce305ece67d78947c0751622e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5_lu8woj/wheels/a5/48/cf/d564a0a8905c98c64f1af7796be2834fa9cad8ab3a7fe184c0
# Successfully built fairseq
# ...
#   Attempting uninstall: fairseq
#     Found existing installation: fairseq 1.0.0a0+9a1c497
#     Uninstalling fairseq-1.0.0a0+9a1c497:
#       Successfully uninstalled fairseq-1.0.0a0+9a1c497
# ...
# pip install already

# %%
# !pip install pip==23.3.2 # 或者任何低于 24.1 的版本，例如 23.x.x
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 26.8 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
# 尝试安装一个 fairseq 要求的 omegaconf 版本，例如 2.0.6
# !pip install omegaconf==2.0.6
# 卸载可能存在的旧版本 hydra-core，虽然它提示没有安装
# !pip uninstall hydra-core -y

# 安装 hydra-core 1.0.7 (或者其他 1.0.x 版本)
# !pip install hydra-core==1.0.7
# Out:
# ...
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# WARNING: Skipping hydra-core as it is not installed.
# ...
#   Using cached hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 2.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 5.0 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141211 sha256=0918c2cfdb19a8fcd73c8878e61d2c8a9a01984c3a387f9f336f525a9dea250d
# ...

# %%
# !pip uninstall omegaconf -y
# !pip install omegaconf==2.0.6
# Out:
# Found existing installation: omegaconf 2.0.6
# Uninstalling omegaconf-2.0.6:
#   Successfully uninstalled omegaconf-2.0.6
# ...
#   Using cached omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached omegaconf-2.0.6-py3-none-any.whl (36 kB)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...

# %%
# 2. 卸载可能存在的 hydra-core (虽然提示没有，但为了确保干净，执行一下无妨)
# !pip uninstall hydra-core -y

# 3. 安装 hydra-core 的兼容版本 (小于 1.1)
# !pip install hydra-core==1.0.7
# Out:
# Found existing installation: hydra-core 1.0.7
# Uninstalling hydra-core-1.0.7:
#   Successfully uninstalled hydra-core-1.0.7
# ...
#   Using cached hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# ...
# Using cached hydra_core-1.0.7-py3-none-any.whl (123 kB)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...

# %%
# 如果你之前安装过 fairseq，可以尝试重新安装以确保依赖正确解析

# !pip uninstall fairseq -y
# !pip install fairseq==0.12.2
# Out:
# Found existing installation: fairseq 1.0.0a0+9a1c497
# Uninstalling fairseq-1.0.0a0+9a1c497:
#   Successfully uninstalled fairseq-1.0.0a0+9a1c497
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 22.5 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.0/316.0 kB 18.9 MB/s eta 0:00:00
# ...
#   Created wheel for fairseq: filename=fairseq-0.12.2-cp311-cp311-linux_x86_64.whl size=11352322 sha256=8e4294c7d1c020e6b8797485cb4c7bd4a451e3fb22f6efdba70328c4f8db6ecf
#   Stored in directory: /root/.cache/pip/wheels/f1/0d/ed/f4ca5b65eef7dda06cb421355a049648c032c6322c455a396e
# Successfully built fairseq
# ...

# %%
# !pip list
# Out:
# Package                            Version             Editable project location
# ---------------------------------- ------------------- -------------------------
# absl-py                            1.4.0
# accelerate                         1.5.2
# aiofiles                           22.1.0
# aiohappyeyeballs                   2.6.1
# aiohttp                            3.11.18
# aiosignal                          1.3.2
# aiosqlite                          0.21.0
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.5
# ale-py                             0.10.2
# alembic                            1.15.2
# altair                             5.5.0
# annotated-types                    0.7.0
# annoy                              1.17.3
# ansicolors                         1.1.8
# antlr4-python3-runtime             4.8
# anyio                              4.9.0
# argon2-cffi                        23.1.0
# ...

# %%
import sys
import pdb
import pprint
import logging
import os
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
import numpy as np
import tqdm.auto as tqdm
from pathlib import Path
from argparse import Namespace
from fairseq import utils

import matplotlib.pyplot as plt
print("Import Complete")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_35/1793548818.py in <cell line: 0>()
#      14 from pathlib import Path
#      15 from argparse import Namespace
# ---> 16 from fairseq import utils
#      17
#      18 import matplotlib.pyplot as plt
#
# /usr/local/lib/python3.11/dist-packages/fairseq/__init__.py in <module>
#      18
#      19 # backwards compatibility to support `from fairseq.X import Y`
# ---> 20 from fairseq.distributed import utils as distributed_utils
#      21 from fairseq.logging import meters, metrics, progress_bar  # noqa
#      22
#
# /usr/local/lib/python3.11/dist-packages/fairseq/distributed/__init__.py in <module>
#       5
#       6 from .distributed_timeout_wrapper import DistributedTimeoutWrapper
# ----> 7 from .fully_sharded_data_parallel import (
#       8     fsdp_enable_wrap,
#       9     fsdp_wrap,
#
# ...
